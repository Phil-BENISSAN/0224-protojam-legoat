# %%
import pandas as pd
from fastapi import FastAPI

df_rando = pd.read_csv('rando.csv', sep=',')

app = FastAPI()

def fonction(column,column2,condition):
    all = {}
    for index in range(0,len(df_rando)):

        if df_rando.loc[index,column2] == condition]:

            ligne = {}
                
            ligne[column] = df_rando.loc[index,column]

        all[index] = ligne

    return all

# %%
fonction('uuid','type_itinéraire','Sentier')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 fonction('uuid','type_itinéraire','Sentier')
#
# Cell In[1], line 12, in fonction(column, column2, condition)
#       9 all = {}
#      10 for index in range(0,len(df_rando)):
# ---> 12     if df_rando[df_rando.loc[index,column2] == condition]:
#      13         ligne = {}
#      15         ligne[column] = df_rando.loc[index,column]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: True

# %%
df_rando.drop(columns=['difficulte','altitude_min','altitude_max'],axis=1,inplace=True)

# %%
df_rando.head()
# Out:
#                                    uuid                               depart   \
# 0  2f6b7cfc-e302-49d2-8135-dcfddf26f173   6.353486608102956,45.12166512481137
# 1  907cfe35-7354-4d5b-99d9-2e92bfc93e1d  6.400056711017181,45.119651344179545
# 2  d3a9b9c7-12a2-4f0d-8690-86c274e57bc0    6.388940896866119,45.1206128701586
# 3  dfb4c8ec-8f7d-47b4-a2b8-b06c3482fe7c   6.391030205194402,45.12033883819788
# 4  d760af8b-0bc2-4975-b29f-60b69652e38c   6.405371952368392,45.11950457648529
#
#                                 arrivée type_itinéraire          type_sol  \
# 0  6.384971672787728,45.121389878464576         Sentier  Cailloux + terre
# 1    6.388940896866119,45.1206128701586         Sentier  Cailloux + terre
# 2   6.384971672756636,45.12138987750839         Sentier  Cailloux + terre
# 3  6.398946738784744,45.122106631651405         Sentier  Cailloux + terre
# 4  6.403838260879247,45.120279020076715         Sentier  Cailloux + terre
#
#   longueur largeur etat_itineraire
# 0  3021.87   0,4 m             Bon
# 1   898.28   0,4 m             Bon
# 2    331.1   0,4 m             Bon
# 3   665.62   0,4 m       Assez bon
# 4   158.29   0,4 m             Bon

# %%
all = {}
for index in range(0,len(df_rando)):
    
    ligne = {}
    for column in df_rando.columns:
        
        ligne[column] = df_rando.loc[index,column]

    all[index] = ligne

return all
# Out:
# {0: {'uuid': '2f6b7cfc-e302-49d2-8135-dcfddf26f173', 'depart ': '6.353486608102956,45.12166512481137', 'arrivée': '6.384971672787728,45.121389878464576', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '3021.87', 'largeur': '0,4 m', 'etat_itineraire': 'Bon'}, 1: {'uuid': '907cfe35-7354-4d5b-99d9-2e92bfc93e1d', 'depart ': '6.400056711017181,45.119651344179545', 'arrivée': '6.388940896866119,45.1206128701586', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '898.28', 'largeur': '0,4 m', 'etat_itineraire': 'Bon'}, 2: {'uuid': 'd3a9b9c7-12a2-4f0d-8690-86c274e57bc0', 'depart ': '6.388940896866119,45.1206128701586', 'arrivée': '6.384971672756636,45.12138987750839', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '331.1', 'largeur': '0,4 m', 'etat_itineraire': 'Bon'}, 3: {'uuid': 'dfb4c8ec-8f7d-47b4-a2b8-b06c3482fe7c', 'depart ': '6.391030205194402,45.12033883819788', 'arrivée': '6.398946738784744,45.122106631651405', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '665.62', 'largeur': '0,4 m', 'etat_itineraire': 'Assez bon'}, 4: {'uuid': 'd760af8b-0bc2-4975-b29f-60b69652e38c', 'depart ': '6.405371952368392,45.11950457648529', 'arrivée': '6.403838260879247,45.120279020076715', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '158.29', 'largeur': '0,4 m', 'etat_itineraire': 'Bon'}, 5: {'uuid': '29c15b39-474a-4475-8f4e-eca3e0d99aec', 'depart ': '6.411117292787321,45.11872820991772', 'arrivée': '6.415287442922735,45.11956108723733', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '616.08', 'largeur': '0,8 m', 'etat_itineraire': 'Bon'}, 6: {'uuid': 'b7840b89-3a4b-44fa-b37a-72ac3436e296', 'depart ': '6.405309497561927,45.13505128199385', 'arrivée': '6.40676752756455,45.13462526213617', 'type_itinéraire': 'Chemin', 'type_sol': 'Cailloux', 'longueur': '261.33', 'largeur': '2,00 m', 'etat_itineraire': 'Bon'}, 7: {'uuid': '89b8c76f-0fc5-4b45-a476-d717dbe5c1af', 'depart ': '6.403838260879247,45.120279020076715', 'arrivée': '6.400056711017181,45.119651344179545', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '321.75', 'largeur': '0,4 m', 'etat_itineraire': 'Bon'}, 8: {'uuid': '4d6d7758-74ff-41c1-9886-8564eb83821e', 'depart ': '6.401814894228019,45.12393277860941', 'arrivée': '6.398946738784744,45.122106631651405', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '309.13', 'largeur': '0,4 m', 'etat_itineraire': 'Assez bon'}, 9: {'uuid': '3922351a-b738-40f3-8aa8-60d1d8718c8c', 'depart ': '6.406851000030617,45.119290300809205', 'arrivée': '6.405371952368392,45.11950457648529', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '136.5', 'largeur': '0,4 m', 'etat_itineraire': 'Bon'}, 10: {'uuid': '6777b5ee-fa35-453f-9d05-1b32c0c3b447', 'depart ': '6.401814894228019,45.12393277860941', 'arrivée': '6.404646199160979,45.13295763345162', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '1169.36', 'largeur': '0,4 m', 'etat_itineraire': 'Assez bon'}, 11: {'uuid': '0a45491c-3166-41e2-85c6-1b70480ff452', 'depart ': '6.409531316908097,45.119026687086766', 'arrivée': '6.406851000030617,45.119290300809205', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '227.2', 'largeur': '0,4 m', 'etat_itineraire': 'Bon'}, 12: {'uuid': '2635ed71-e181-4336-9d34-315e9ddee40d', 'depart ': '6.411117292787316,45.11872820991774', 'arrivée': '6.409531316908097,45.119026687086766', 'type_itinéraire': 'Sentier', 'type_sol': 'Herbe + terre', 'longueur': '143.2', 'largeur': '0,4 m', 'etat_itineraire': 'Bon'}, 13: {'uuid': '1a661257-cf7f-4935-b68b-6e5d8a4cff3a', 'depart ': '6.411617699316819,45.120313300980776', 'arrivée': '6.409531316908097,45.119026687086766', 'type_itinéraire': 'Sentier', 'type_sol': 'Cailloux + terre', 'longueur': '223.44', 'largeur': '0,4 m', 'etat_itineraire': 'Assez bon'}, 14: {'uuid': ...

# %%
app = FastAPI()


@app.get('/')
def all() -> dict:
    """
    Affiche toutes les données
    """
    all = {}
    for index in range(0,len(df_rando)):
        
        ligne = {}
        for column in df_rando.columns:
            
            ligne[column] = df_rando.loc[index,column]

        all[index] = ligne

    return all
